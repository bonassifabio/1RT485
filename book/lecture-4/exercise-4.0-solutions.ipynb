% %% [markdown]
% (ref:lec4:ex0_sol)=
% # Solutions of Exercise 4.0

% %% [markdown]
% We are given a mechanical system represented by the transfer function $G(s)$. While an explicit expression for $G(s)$ is not available, we have obtained its frequency response through a lot of [hammer tests](https://en.wikipedia.org/wiki/Modal_testing). The resulting frequency response is depicted in {numref}`fig:lec4:ex0_sol:bode` below.

% %% [markdown]
% ```{figure} res/ex0-bode.svg
% ---
% width: 750px
% name: fig:lec4:ex0_sol:bode
% ---
% Bode plot of the mechanical system $G(s)$
% ```

% %% [markdown]
% 1. Design a proportional controller $F(s)=K$ such that the following specifications are satisfied:
%    - The closed-loop is stable.
%    - The bandwidth is greater than $5$ rad/s, but it does not exceed $15$ rad/s.
%    - The phase margin $\varphi_m$ is larger than $45^\circ$.
% 2. What will be the worst-case resonance peak of the closed-loop transfer function $G_c(s)$?

% %% [markdown]
% ```{admonition} Hint
% :class: hint
%
% Let the open-loop transfer function be $G_o(s) = F(s) G(s)$. Then, its modulus and phase read
%
% $$
% \lvert G_o(i \omega) \lvert_{\text{dB}} = \lvert F(i \omega) \lvert_{\text{dB}}  + \lvert G(i \omega) \lvert_{\text{dB}}
% $$ (eq:lec4:ex0_sol:modulus)
%
% $$
% \angle G_o(i \omega) = \angle F(i \omega) + \angle G(i \omega)
% $$ (eq:lec4:ex0_sol:phase)
%
% ```

% %% [markdown]
% ---

% %% [markdown]
% ## Solution

% %% [markdown]
% ### Question 1

% %% [markdown]
% Let's start by noting that according to {eq}`eq:lec4:ex0_sol:modulus` and {eq}`eq:lec4:ex0_sol:phase`, the Bode plots of $G_o(s)$ (and hence the closed-loop performance) can be inferred from the Bode plots of $G(s)$ without actually knowing its analytical expression!
%
% - {eq}`eq:lec4:ex0_sol:modulus` implies that $\lvert G_o(i \omega) \lvert_{\text{dB}}$ is obtained by shifting $\lvert G(i \omega) \lvert_{\text{dB}}$ up/down by $\lvert F(i \omega) \lvert_{\text{dB}} = K_{\text{dB}} = 20 \log_{10} K$
% - {eq}`eq:lec4:ex0_sol:phase` implies that $\angle G_o(i \omega)$ remains unchanged, because $\angle F(i \omega) = 0^\circ$ as long as $K > 0$

% %% [markdown]
% ```{note}
% The closed-loop bandwidth is approximately equal to the critical frequency of the open-loop transfer function $G_o(i\omega)$, i.e., the frequency $\omega_c$ where $\lvert G_o(i \omega_c) \lvert_{\text{dB}}$ cuts the $0$ dB axis.
% ```

% %% [markdown]
% Inspecting {numref}`fig:lec4:ex0_sol:bode`, we realize that $\omega_c = 5$ if $K_{\text{dB}} = 22$ dB. Similarly, $\omega_c = 15$ if $K_{\text{dB}} = 48$ dB. The resulting Bode plots of $G_o(s)$ are repoted in {numref}`fig:lec4:ex0:bode-sol`.
%
% ```{figure} res/ex0-bode-sol-mag.svg
% ---
% width: 750px
% name: fig:lec4:ex0:bode-sol
% ---
% Bode plot of $G_o(s)$ for $K_{\text{dB}} = 22$ dB (blue line) and for $K_{\text{dB}} = 48$ dB (red line).
% ```

% %% [markdown]
% Therefore, the range of gains statisfying the bandwidth requirement is
%
% $$
% 12.6 \leq K \leq  250
% $$

% %% [markdown]
% As for the phase, $\angle G_o(i \omega) = \angle G(i \omega)$ for any $K > 0$. Therefore, the phase margin $\varphi_m$ is bigger than $45^\circ$ as long as at the critical frequency $\omega_c$, the phase satisfies $\angle G(i \omega_c) > -135^\circ$.
%
% Inspecting {numref}`fig:lec4:ex0_sol:bode`, we can see that this is the case as long as $\omega_c > 8$ rad/s. This condition on the critical frequency is satisfied for $K_{\text{dB}} > 28 $ dB, hence
%
% $$
% K \geq 25
% $$
%
% **Solution**: Any $K$ in the range $25 \leq K \leq 250$ satisfies the requirements.

% %% [markdown]
% ### Question 2
%
% As seen during the lecture F6, the closed-loop resonance peak satisfies
%
% $$
% M_p \leq \frac{1}{2 \sin\left( \frac{\varphi_m}{2} \right)}
% $$
%
% The worst-case resonance peak happens at the minimum phase margin, $\varphi_m = 45^\circ$, at which $M_p = 1.3$.
